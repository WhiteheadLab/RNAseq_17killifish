# %%
import os
import pandas as pd
# requires dammit env
# source activate dammit
from dammit.fileio.gff3 import GFF3Parser

# %% [markdown]
# # Make list of genes being quantified
#
# Salmon was run with the de novo transcriptome assemblies, with the original Trinity ID in the header for each fasta contig record, like this (example salmon output file):
#
# ```
# Name	Length	EffectiveLength	TPM	NumReads
# TRINITY_DN2202_c0_g1_i1	210	39.818	2.683835	2.000000
# TRINITY_DN2270_c0_g1_i1	213	41.064	0.000000	0.000000
# TRINITY_DN2201_c0_g1_i1	266	69.681	0.766816	1.000000
# TRINITY_DN2222_c0_g1_i1	243	55.794	2.873014	3.000000
# TRINITY_DN2291_c0_g1_i1	245	56.916	0.000000	0.000000
# TRINITY_DN2269_c0_g1_i1	294	89.251	0.000000	0.000000
# TRINITY_DN2269_c1_g1_i1	246	57.479	0.000000	0.000000
# TRINITY_DN2279_c0_g1_i1	426	207.443	0.000000	0.000000
# TRINITY_DN2262_c0_g1_i1	500	280.803	0.190459	1.000912
# TRINITY_DN2253_c0_g1_i1	1523	1303.116	0.164015	4.000000
# TRINITY_DN2287_c0_g1_i1	467	247.962	0.000000	0.000000
# TRINITY_DN2287_c1_g1_i1	325	113.826	0.469425	1.000000
# TRINITY_DN2237_c0_g1_i1	306	98.441	0.542788	1.000000
# TRINITY_DN2237_c0_g2_i1	307	99.229	0.000000	0.000000
# TRINITY_DN2250_c0_g1_i1	368	151.832	0.000000	0.000000
# TRINITY_DN2250_c1_g1_i1	271	72.988	0.000000	0.000000
# TRINITY_DN2208_c0_g1_i1	379	162.080	1.978014	6.000000
# TRINITY_DN2277_c0_g1_i1	269	71.657	0.745677	1.000000
# TRINITY_DN2231_c0_g1_i1	209	39.409	0.000000	0.000000
# TRINITY_DN2231_c1_g1_i1	334	121.411	0.000000	0.000000
# TRINITY_DN2204_c0_g1_i1	287	84.121	0.000000	0.000000
# ```
#
# Takes each salmon output .quant file (like the one above), parse the "i" (isoform) off of the ID to get a list of genes and isoforms identified by Trinity.

# %%
species_dirs = "../salmon_denovo_by_species"
out_dir = "/Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/"
dirs = os.listdir(species_dirs)
for species in dirs:
    if species != ".DS_Store":
        count = 0
        species_gene_file = out_dir + species + "_contig_gene.csv"
        files = os.listdir(species_dirs + "/" + species)
        for quant_dir in files:
            if quant_dir != ".DS_Store":
                while count == 0:
                    replicate = quant_dir.split(".")[0]
                    print(replicate)
                    quant_files = os.listdir(species_dirs + "/" + species + "/" + quant_dir)
                    for file in quant_files:
                        if file.endswith(".sf"):
                            table = pd.read_csv(species_dirs + "/" + species + "/" + quant_dir + "/" + file,sep="\t")
                            print("Contigs:",table.shape)
                            contig_names = pd.DataFrame(table.Name.str.split("_",5).tolist(),columns = ['Trinity','Contig','Component','Gene','Isoform'])
                            contig_names2 = pd.DataFrame()
                            contig_names2['Name'] = contig_names[['Trinity','Contig','Component','Gene','Isoform']].apply(lambda x: '_'.join(x),axis=1)
                            contig_names2['Gene'] = contig_names[['Trinity','Contig','Component','Gene']].apply(lambda x: '_'.join(x),axis=1)
                            print("Trinity 'genes':",contig_names2['Gene'].nunique())
                            contig_names2.to_csv(species_gene_file)
                            print("File written:",species_gene_file)
                            count += 1
# Out:
# L_goodei_transfer_2
# Contigs: (385474, 5)
# Trinity 'genes': 266317
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/L_goodei_contig_gene.csv
# F_notti_FW_2
# Contigs: (159768, 5)
# Trinity 'genes': 123565
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/F_nottii_contig_gene.csv
# L_parva_FW_3
# Contigs: (409536, 5)
# Trinity 'genes': 275950
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/L_parva_contig_gene.csv
# F_similis_transfer_1
# Contigs: (520315, 5)
# Trinity 'genes': 392860
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/F_similis_contig_gene.csv
# F_olivaceous_FW_2
# Contigs: (350264, 5)
# Trinity 'genes': 248630
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/F_olivaceus_contig_gene.csv
# F_notatus_FW_2
# Contigs: (416296, 5)
# Trinity 'genes': 286353
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/F_notatus_contig_gene.csv
# F_heteroclitusMDPP_FW_3
# Contigs: (668484, 5)
# Trinity 'genes': 496133
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/F_heteroclitusMDPP_contig_gene.csv
# F_heteroclitusMDPL_transfer_3
# Contigs: (592415, 5)
# Trinity 'genes': 392026
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/F_heteroclitusMDPL_contig_gene.csv
# F_parvapinis_FW_1
# Contigs: (352342, 5)
# Trinity 'genes': 279009
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/F_parvapinis_contig_gene.csv
# F_diaphanus_BW_1
# Contigs: (384216, 5)
# Trinity 'genes': 288318
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/F_diaphanus_contig_gene.csv
# F_catanatus_BW_2
# Contigs: (405863, 5)
# Trinity 'genes': 283212
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/F_catanatus_contig_gene.csv
# F_zebrinus_FW_2
# Contigs: (266977, 5)
# Trinity 'genes': 194115
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/F_zebrinus_contig_gene.csv
# F_sciadicus_transfer_1
# Contigs: (241279, 5)
# Trinity 'genes': 178995
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/F_sciadicus_contig_gene.csv
# F_grandis_transfer_3
# Contigs: (809057, 5)
# Trinity 'genes': 608505
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/F_grandis_contig_gene.csv
# F_rathbuni_BW_2
# Contigs: (501215, 5)
# Trinity 'genes': 364231
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/F_rathbuni_contig_gene.csv
# F_chrysotus_BW_2
# Contigs: (396398, 5)
# Trinity 'genes': 269787
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/F_chrysotus_contig_gene.csv
# A_xenica_FW_2
# Contigs: (362782, 5)
# Trinity 'genes': 248903
# File written: /Users/johnsolk/Documents/UCDavis/Whitehead/gene_name_counts_23June2018/A_xenica_contig_gene.csv

# %% [markdown]
# # 2. Run tximport in R

# %% [markdown]
# # 3. Merge annotations for each species, connecting Trinity contigs/genes to annotation

# %%
species_dirs = "../salmon_denovo_by_species"

# %%
table = pd.read_csv("/Users/johnsolk/Documents/UCDavis/Whitehead/RNAseq_15killifish/salmon_denovo_by_species/L_goodei/L_goodei_transfer_2.quant/quant.sf",sep="\t")
table.head()
table.shape
# Out:
# (385474, 5)

# %%
table = pd.read_csv("../salmon_denovo_by_speciesout_dir" + "F_heteroclitusMDPL_trinity_contig_gene_table.txt",sep="\t")
table.head()
# Out:
#    TRINITY_DN2271_c0_g1_i1  TRINITY_DN2271_c0_g1
# 0  TRINITY_DN2222_c0_g1_i1  TRINITY_DN2222_c0_g1
# 1  TRINITY_DN2222_c1_g1_i1  TRINITY_DN2222_c1_g1
# 2  TRINITY_DN2209_c0_g1_i1  TRINITY_DN2209_c0_g1
# 3  TRINITY_DN2281_c0_g1_i1  TRINITY_DN2281_c0_g1
# 4  TRINITY_DN2240_c0_g1_i1  TRINITY_DN2240_c0_g1

# %% [markdown]
# # Using dammit's `GFF3Parser` function
# 1. Digests the gff3 file for each species (output from dammit, downloaded from the farm cluster)
# 2. Sorts each contig by E-value score
# 3. Assigns the lowest E-value score for each contig
# 4. Separately, for each contig, saves gene names from the NCBI annotated F. heteroclitus genome

# %%
annotations_dir = "/Users/johnsolk/Documents/UCDavis/Whitehead/gff_annotations/"
conversion_dir = "/Users/johnsolk/Documents/UCDavis/Whitehead/dammit_conversions/"
Fhet_counts_dir = "/Users/johnsolk/Documents/UCDavis/Whitehead/Fhet_counts/"
annotations = os.listdir(annotations_dir)
conversions = os.listdir(conversion_dir)
for annotation in annotations:
    if annotation != ".DS_Store":
        species = annotation.split(".")[0]
        if species == "F_olivaceous":
            species = "F_olivaceus"
        if species == "F_notti":
            species = "F_nottii"
        print(species)
        print(annotation)
        name = annotations_dir + annotation
        annotations = GFF3Parser(filename=name).read()
        annotations = annotations.dropna(subset=['Name'])
        annotations["length"] = annotations["end"].subtract(annotations["start"], fill_value=0)
        pickonename = annotations.sort_values(by=['seqid', 'score'], ascending=True).query('score < 1e-05').drop_duplicates(subset='seqid')[['seqid', 'Name','Note','database','Dbxref','start','end','length']]
        pickonename = pickonename.dropna(axis=0,how="all")
        print('Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):')
        print(pickonename.shape)
        contigs_w_expression = pd.read_csv(out_dir + species + '_trinity_contig_gene_table_filtered.txt',sep="\t",names = ['contig','gene'])
        contigs = species + "_trinity_contig_gene_table.txt"
        contigs_table = pd.read_csv(out_dir + contigs,sep="\t",names = ['contig','gene'])
        print('Number of contigs:')
        print(contigs_table.shape)
        conversion_file = [i for i in conversions if i.startswith(species)][0]
        conversion = pd.read_csv(conversion_dir + conversion_file)
        conversion['contig'], conversion['info'] = conversion['original'].str.split(' ', 1).str
        conversion = conversion[['contig','renamed']]
        contigs_w_expression_conversion = pd.merge(conversion, contigs_w_expression, on="contig")
        contigs_w_expression_conversion.columns = ['contig','seqid','gene']
        annotations_expression = pd.merge(contigs_w_expression_conversion,pickonename,on='seqid')
        print("Number of unique gene names:")
        print(len(annotations_expression.Name.unique()))
        fhet = annotations[annotations['Name'].str.startswith("gi")]
        fhet_filtered = fhet.query('score < 1e-05').drop_duplicates(subset='seqid')[['seqid', 'Name','start','end','length']]
        print("Number of Fhet gene names:")
        print(len(fhet_filtered.Name.unique()))
        fhet_out = Fhet_counts_dir + species + "_genenames.csv"
        fhet_filtered.to_csv(fhet_out)
        fhet_annotations_epxression = pd.merge(annotations_expression,fhet_filtered,on='seqid',how='inner')
        names = fhet_annotations_epxression.drop_duplicates(subset='seqid')
        # filetered out contigs with no expression
        names = names.dropna(subset=['Name_x'])
        names_out = "/Users/johnsolk/Documents/UCDavis/Whitehead/annotation_files_test/" + species + "_genenames.csv"
        names.to_csv(names_out)
# Out:
# F_notatus
# F_notatus.trinity_out.Trinity.fasta.dammit.gff3
# /Users/johnsolk/anaconda3/lib/python3.6/site-packages/dammit/fileio/gff3.py:73: ParserWarning: Both a converter and dtype were specified for column attributes - only the converter will be used
#   dtype=dict(self.columns)):
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (167061, 8)
# Number of contigs:
# (416296, 2)
# Number of unique gene names:
# 37751
# Number of Fhet gene names:
# 22530
# F_rathbuni
# F_rathbuni.trinity_out.Trinity.fasta.dammit.gff3
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (176367, 8)
# Number of contigs:
# (501215, 2)
# Number of unique gene names:
# 40216
# Number of Fhet gene names:
# 22718
# F_diaphanus
# F_diaphanus.trinity_out.Trinity.fasta.dammit.gff3
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (128323, 8)
# Number of contigs:
# (384216, 2)
# Number of unique gene names:
# 36687
# Number of Fhet gene names:
# 21624
# F_chrysotus
# F_chrysotus.trinity_out.Trinity.fasta.dammit.gff3
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (155206, 8)
# Number of contigs:
# (396398, 2)
# Number of unique gene names:
# 38576
# Number of Fhet gene names:
# 22455
# L_goodei
# L_goodei.trinity_out.Trinity.fasta.dammit.gff3
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (138485, 8)
# Number of contigs:
# (385474, 2)
# Number of unique gene names:
# 35129
# Number of Fhet gene names:
# 22631
# F_heteroclitusMDPL
# F_heteroclitusMDPL.trinity_out.Trinity.fasta.dammit.gff3
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (188268, 8)
# Number of contigs:
# (592415, 2)
# Number of unique gene names:
# 39563
# Number of Fhet gene names:
# 22849
# F_heteroclitusMDPP
# F_heteroclitusMDPP.trinity_out.Trinity.fasta.dammit.gff3
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (186798, 8)
# Number of contigs:
# (668484, 2)
# Number of unique gene names:
# 39072
# Number of Fhet gene names:
# 22994
# F_similis
# F_similis.trinity_out.Trinity.fasta.dammit.gff3
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (154675, 8)
# Number of contigs:
# (520315, 2)
# Number of unique gene names:
# 37209
# Number of Fhet gene names:
# 22338
# L_parva
# L_parva.trinity_out.Trinity.fasta.dammit.gff3
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (145529, 8)
# Number of contigs:
# (409536, 2)
# Number of unique gene names:
# 37684
# Number of Fhet gene names:
# 22601
# A_xenica
# A_xenica.trinity_out.Trinity.fasta.dammit.gff3
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (148980, 8)
# Number of contigs:
# (362782, 2)
# Number of unique gene names:
# 37921
# Number of Fhet gene names:
# 21806
# F_catanatus
# F_catanatus.trinity_out.Trinity.fasta.dammit.gff3
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (164596, 8)
# Number of contigs:
# (405863, 2)
# Number of unique gene names:
# 41933
# Number of Fhet gene names:
# 22435
# F_zebrinus
# F_zebrinus.trinity_out.Trinity.fasta.dammit.gff3
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (102046, 8)
# Number of contigs:
# (266977, 2)
# Number of unique gene names:
# 33694
# Number of Fhet gene names:
# 20439
# F_parvapinis
# F_parvapinis.trinity_out.Trinity.fasta.dammit.gff3
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (126200, 8)
# Number of contigs:
# (352342, 2)
# Number of unique gene names:
# 34375
# Number of Fhet gene names:
# 20647
# F_grandis
# F_grandis.trinity_out.Trinity.fasta.dammit.gff3
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (234074, 8)
# Number of contigs:
# (809057, 2)
# Number of unique gene names:
# 36224
# Number of Fhet gene names:
# 24275
# F_sciadicus
# F_sciadicus.trinity_out.Trinity.fasta.dammit.gff3
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (98332, 8)
# Number of contigs:
# (241279, 2)
# Number of unique gene names:
# 29980
# Number of Fhet gene names:
# 20382
# F_olivaceus
# F_olivaceous.trinity_out.Trinity.fasta.dammit.gff3
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (134207, 8)
# Number of contigs:
# (350264, 2)
# Number of unique gene names:
# 37459
# Number of Fhet gene names:
# 21600
# F_nottii
# F_notti.trinity_out.Trinity.fasta.dammit.gff3
# Number of contigs with annotations (one annotation/contig, sorted by E-value < 1e-05 and picked the lowest):
# (69247, 8)
# Number of contigs:
# (159768, 2)
# Number of unique gene names:
# 28788
# Number of Fhet gene names:
# 18280

# %% [markdown]
# # *Fundulus heteroclitus* gene models only

# %%
RefSeq_NCBI_annotations = GFF3Parser(filename="/Users/johnsolk/Documents/UCDavis/Whitehead/tmp_Fhet_files/ref_Fundulus_heteroclitus-3.0.2_top_level.gff3").read()
# Out:
# /Users/johnsolk/anaconda3/lib/python3.6/site-packages/dammit/fileio/gff3.py:73: ParserWarning: Both a converter and dtype were specified for column attributes - only the converter will be used
#   dtype=dict(self.columns)):

# %%
RefSeq_NCBI_annotations.head()
# Out:
#                                     Dbxref  Gap     ID Is_circular  \
# 0                               taxon:8078  NaN    id0         NaN
# 1                         GeneID:105920463  NaN  gene0         NaN
# 2  GeneID:105920463,Genbank:XM_012856390.2  NaN   rna0         NaN
# 3  GeneID:105920463,Genbank:XM_012856390.2  NaN    id1         NaN
# 4  GeneID:105920463,Genbank:XM_012856390.2  NaN    id2         NaN
#
#              Name Note Parent Target anticodon chromosome        ...         \
# 0         Unknown  NaN    NaN    NaN       NaN    Unknown        ...
# 1            cdx1  NaN    NaN    NaN       NaN        NaN        ...
# 2  XM_012856390.2  NaN  gene0    NaN       NaN        NaN        ...
# 3             NaN  NaN   rna0    NaN       NaN        NaN        ...
# 4             NaN  NaN   rna0    NaN       NaN        NaN        ...
#
#   splices standard_name  start start_range  strand   transcript_id  \
# 0     NaN           NaN      0         NaN       +             NaN
# 1     NaN           NaN   5029         NaN       -             NaN
# 2     NaN           NaN   5029         NaN       -  XM_012856390.2
# 3     NaN           NaN  10044         NaN       -  XM_012856390.2
# 4     NaN           NaN   8334         NaN       -  XM_012856390.2
#
#   transl_except transl_table    type weighted_identity
# 0           NaN          NaN  region               NaN
# 1           NaN          NaN    gene               NaN
# 2           NaN          NaN    mRNA               NaN
# 3           NaN          NaN    exon               NaN
# 4           NaN          NaN    exon               NaN
#
# [5 rows x 61 columns]

# %%
# Convert protein ID, e.g. "XP_" to gene ID
# how many gene models?
RefSeq_NCBI_genenames = RefSeq_NCBI_annotations.dropna(subset=['seqid','Dbxref','transcript_id']).drop_duplicates(subset='Dbxref')[['seqid','Dbxref','transcript_id']]

# %%
print(RefSeq_NCBI_genenames.shape)
# Out:
# (41170, 3)

# %%
print(RefSeq_NCBI_genenames.head())
# Out:
#               seqid                                   Dbxref   transcript_id
# 2    NW_012224401.1  GeneID:105920463,Genbank:XM_012856390.2  XM_012856390.2
# 10   NW_012224401.1  GeneID:105915213,Genbank:XM_021321288.1  XM_021321288.1
# 54   NW_012224401.1  GeneID:105915271,Genbank:XM_012849362.2  XM_012849362.2
# 98   NW_012224401.1  GeneID:105915271,Genbank:XM_012849437.2  XM_012849437.2
# 143  NW_012224401.1  GeneID:105915419,Genbank:XM_021323826.1  XM_021323826.1

# %%
RefSeq_NCBI_genenames['split_1'], RefSeq_NCBI_genenames['split_2'], RefSeq_NCBI_genenames['split_3'] = RefSeq_NCBI_genenames['Dbxref'].str.split(':',0).str

# %%
print(RefSeq_NCBI_genenames.head())
# Out:
#               seqid                                   Dbxref   transcript_id  \
# 2    NW_012224401.1  GeneID:105920463,Genbank:XM_012856390.2  XM_012856390.2
# 10   NW_012224401.1  GeneID:105915213,Genbank:XM_021321288.1  XM_021321288.1
# 54   NW_012224401.1  GeneID:105915271,Genbank:XM_012849362.2  XM_012849362.2
# 98   NW_012224401.1  GeneID:105915271,Genbank:XM_012849437.2  XM_012849437.2
# 143  NW_012224401.1  GeneID:105915419,Genbank:XM_021323826.1  XM_021323826.1
#
#     split_1            split_2         split_3
# 2    GeneID  105920463,Genbank  XM_012856390.2
# 10   GeneID  105915213,Genbank  XM_021321288.1
# 54   GeneID  105915271,Genbank  XM_012849362.2
# 98   GeneID  105915271,Genbank  XM_012849437.2
# 143  GeneID  105915419,Genbank  XM_021323826.1

# %%
RefSeq_NCBI_genenames_sub = RefSeq_NCBI_genenames[(RefSeq_NCBI_genenames["split_1"] == 'GeneID')]
print(RefSeq_NCBI_genenames_sub.head())
# Out:
#               seqid                                   Dbxref   transcript_id  \
# 2    NW_012224401.1  GeneID:105920463,Genbank:XM_012856390.2  XM_012856390.2
# 10   NW_012224401.1  GeneID:105915213,Genbank:XM_021321288.1  XM_021321288.1
# 54   NW_012224401.1  GeneID:105915271,Genbank:XM_012849362.2  XM_012849362.2
# 98   NW_012224401.1  GeneID:105915271,Genbank:XM_012849437.2  XM_012849437.2
# 143  NW_012224401.1  GeneID:105915419,Genbank:XM_021323826.1  XM_021323826.1
#
#     split_1            split_2         split_3
# 2    GeneID  105920463,Genbank  XM_012856390.2
# 10   GeneID  105915213,Genbank  XM_021321288.1
# 54   GeneID  105915271,Genbank  XM_012849362.2
# 98   GeneID  105915271,Genbank  XM_012849437.2
# 143  GeneID  105915419,Genbank  XM_021323826.1

# %%
RefSeq_NCBI_genenames_sub['GeneID'], RefSeq_NCBI_genenames_sub['Genbank'] = RefSeq_NCBI_genenames_sub['split_2'].str.split(',', 0).str

# %%
print(RefSeq_NCBI_genenames_sub.head())
# Out:
#               seqid                                   Dbxref   transcript_id  \
# 2    NW_012224401.1  GeneID:105920463,Genbank:XM_012856390.2  XM_012856390.2
# 10   NW_012224401.1  GeneID:105915213,Genbank:XM_021321288.1  XM_021321288.1
# 54   NW_012224401.1  GeneID:105915271,Genbank:XM_012849362.2  XM_012849362.2
# 98   NW_012224401.1  GeneID:105915271,Genbank:XM_012849437.2  XM_012849437.2
# 143  NW_012224401.1  GeneID:105915419,Genbank:XM_021323826.1  XM_021323826.1
#
#     split_1            split_2         split_3     GeneID  Genbank
# 2    GeneID  105920463,Genbank  XM_012856390.2  105920463  Genbank
# 10   GeneID  105915213,Genbank  XM_021321288.1  105915213  Genbank
# 54   GeneID  105915271,Genbank  XM_012849362.2  105915271  Genbank
# 98   GeneID  105915271,Genbank  XM_012849437.2  105915271  Genbank
# 143  GeneID  105915419,Genbank  XM_021323826.1  105915419  Genbank

# %%
geneID_unique_scaffold = RefSeq_NCBI_genenames_sub.dropna(subset=['GeneID','seqid','transcript_id']).drop_duplicates(subset='seqid')[['GeneID','seqid','transcript_id']]
print(geneID_unique_scaffold.head())
print(geneID_unique_scaffold.shape)
# Out:
#           GeneID           seqid   transcript_id
# 2      105920463  NW_012224401.1  XM_012856390.2
# 7500   105932240  NW_012224402.1  XM_021322060.1
# 13527  105915837  NW_012224403.1  XM_021309415.1
# 17167  105916749  NW_012224404.1  XM_021310176.1
# 21573  110366941  NW_012224405.1  XM_021310901.1
# (3260, 3)

# %%
geneID = RefSeq_NCBI_genenames_sub.dropna(subset=['GeneID','seqid','transcript_id']).drop_duplicates(subset='GeneID')[['GeneID','seqid','transcript_id']]
print(geneID.head())
print(geneID.shape)
# Out:
#         GeneID           seqid   transcript_id
# 2    105920463  NW_012224401.1  XM_012856390.2
# 10   105915213  NW_012224401.1  XM_021321288.1
# 54   105915271  NW_012224401.1  XM_012849362.2
# 143  105915419  NW_012224401.1  XM_021323826.1
# 228  110366472  NW_012224401.1  XM_021307801.1
# (25600, 3)

# %%
transcript_ID = RefSeq_NCBI_genenames_sub.dropna(subset=['GeneID','seqid','transcript_id']).drop_duplicates(subset='transcript_id')[['GeneID','seqid','transcript_id']]
print(transcript_ID.head())
print(transcript_ID.shape)
# Out:
#         GeneID           seqid   transcript_id
# 2    105920463  NW_012224401.1  XM_012856390.2
# 10   105915213  NW_012224401.1  XM_021321288.1
# 54   105915271  NW_012224401.1  XM_012849362.2
# 98   105915271  NW_012224401.1  XM_012849437.2
# 143  105915419  NW_012224401.1  XM_021323826.1
# (41170, 3)

# %%
protein_ID = RefSeq_NCBI_annotations.dropna(subset=['protein_id','seqid','product','gene']).drop_duplicates(subset='protein_id')[['protein_id','seqid','product','gene']]
print(protein_ID.head())
print(protein_ID.shape)
# Out:
#          protein_id           seqid  \
# 6    XP_012711844.1  NW_012224401.1
# 32   XP_021176963.1  NW_012224401.1
# 77   XP_012704816.1  NW_012224401.1
# 121  XP_012704891.1  NW_012224401.1
# 165  XP_021179501.1  NW_012224401.1
#
#                                              product    gene
# 6                             homeobox protein CDX-1    cdx1
# 32      platelet-derived growth factor receptor beta  pdgfrb
# 77   macrophage colony-stimulating factor 1 receptor   csf1r
# 121  macrophage colony-stimulating factor 1 receptor   csf1r
# 165       HMG domain-containing protein 3 isoform X1  hmgxb3
# (38234, 4)

# %%
#merge protein ID and transcript ID
protein_transcript = pd.merge(protein_ID,transcript_ID,how="inner",on="seqid").dropna()
print(protein_transcript.shape)
print(protein_transcript.head())
# Out:
# (3042359, 6)
#        protein_id           seqid                 product  gene     GeneID  \
# 0  XP_012711844.1  NW_012224401.1  homeobox protein CDX-1  cdx1  105920463
# 1  XP_012711844.1  NW_012224401.1  homeobox protein CDX-1  cdx1  105915213
# 2  XP_012711844.1  NW_012224401.1  homeobox protein CDX-1  cdx1  105915271
# 3  XP_012711844.1  NW_012224401.1  homeobox protein CDX-1  cdx1  105915271
# 4  XP_012711844.1  NW_012224401.1  homeobox protein CDX-1  cdx1  105915419
#
#     transcript_id
# 0  XM_012856390.2
# 1  XM_021321288.1
# 2  XM_012849362.2
# 3  XM_012849437.2
# 4  XM_021323826.1

# %%
print("Number of unique scaffold ID ('NW_') :",len(pd.unique(RefSeq_NCBI_annotations['seqid'].dropna())))
print("Number of unique transcripts ('XM_') :",len(pd.unique(RefSeq_NCBI_annotations['transcript_id'].dropna())))
print("Number of unique protein ID ('XP_') :",len(pd.unique(RefSeq_NCBI_annotations['protein_id'].dropna())))
print("Number of unique gene ID (parsed from 'Dbxref') :",len(geneID))
# Out:
# Number of unique scaffold ID ('NW_') : 10180
# Number of unique transcripts ('XM_') : 41170
# Number of unique protein ID ('XP_') : 38234
# Number of unique gene ID (parsed from 'Dbxref') : 25600

# %% [markdown]
# ## Merge NCBI annotations with contigs annotated to Fhet

# %%
# print number of Fhet "genes" in each:
Fhet_counts_dir = "/Users/johnsolk/Documents/UCDavis/Whitehead/Fhet_counts/"
Fhet_counts_ncbi = "/Users/johnsolk/Documents/UCDavis/Whitehead/Fhet_counts_ncbi/"
files = os.listdir(Fhet_counts_dir)
print(files)
for table_file in files:
    if table_file.endswith(".csv"):
        table = pd.read_csv(Fhet_counts_dir + table_file)
        print("Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig):",table.groupby('seqid').count().shape)
        print("Unique Fhet genes:",table.groupby('Name').count().shape)
        table['split_1'], table['split_2'], table['split_3'],table['split_4'],table['split_5'] = table['Name'].str.split('|',0).str
        table.columns = ['index','seqid', 'Name', 'start', 'end', 'length', 'split_1', 'id','split_3', 'protein_id', 'Notes']
        table = table[['seqid', 'Name', 'start', 'end', 'length', 'id','protein_id', 'Notes']]
        table = pd.merge(table,protein_transcript,how="inner",on="protein_id")
        print(table.head())
        table = table.drop_duplicates(subset='seqid_x')[['seqid_x', 'Name', 'start', 'end', 'length', 'id','protein_id', 'Notes','seqid_y','product','gene','GeneID']]
        # there are multiple NCBI GeneID and tarnscript_id per seqid (Trinity transcript)
        # Yet, it's the same protein...
        # Meaning, the Fhet reference is fragemented
        table = table[['seqid_x', 'start', 'end', 'length', 'id','protein_id', 'Notes','seqid_y','product','gene','GeneID']]
        table.columns = ['seqid', 'start', 'end', 'length', 'NCBI.id','NCBI.protein', 'Notes','NCBI.trasncript','NCBI.product','gene','NCBI.gene']
        conversion_file = [i for i in conversions if i.startswith(species)][0]
        conversion = pd.read_csv(conversion_dir + conversion_file)
        conversion['contig'], conversion['info'] = conversion['original'].str.split(' ', 1).str
        conversion = conversion[['contig','renamed']]
        conversion.columns = ['contig','seqid']
        table = pd.merge(conversion, table, on="seqid")
        print(table.head())
        print(table.shape)
        file_out = Fhet_counts_ncbi + table_file + "_NCBI.csv"
        table.to_csv(file_out)
# Out:
# ['F_catanatus_genenames.csv', 'F_chrysotus_genenames.csv', 'F_notatus_genenames.csv', 'F_olivaceus_genenames.csv', 'L_goodei_genenames.csv', 'F_nottii_genenames.csv', '.DS_Store', 'F_grandis_genenames.csv', 'F_diaphanus_genenames.csv', 'A_xenica_genenames.csv', 'F_parvapinis_genenames.csv', 'F_rathbuni_genenames.csv', 'F_similis_genenames.csv', 'F_heteroclitusMDPL_genenames.csv', 'L_parva_genenames.csv', 'F_zebrinus_genenames.csv', 'F_sciadicus_genenames.csv', 'F_heteroclitusMDPP_genenames.csv']
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (78538, 5)
# Unique Fhet genes: (22435, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100057  gi|831528406|ref|XP_012720105.1| PREDICTED: E3...
# 1  Transcript_100057  gi|831528406|ref|XP_012720105.1| PREDICTED: E3...
# 2  Transcript_100057  gi|831528406|ref|XP_012720105.1| PREDICTED: E3...
# 3  Transcript_100057  gi|831528406|ref|XP_012720105.1| PREDICTED: E3...
# 4  Transcript_100057  gi|831528406|ref|XP_012720105.1| PREDICTED: E3...
#
#    start  end  length         id      protein_id  \
# 0     57  287     230  831528406  XP_012720105.1
# 1     57  287     230  831528406  XP_012720105.1
# 2     57  287     230  831528406  XP_012720105.1
# 3     57  287     230  831528406  XP_012720105.1
# 4     57  287     230  831528406  XP_012720105.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: E3 SUMO-protein ligase NSE2 [Fundu...  NW_012234283.1
# 1   PREDICTED: E3 SUMO-protein ligase NSE2 [Fundu...  NW_012234283.1
# 2   PREDICTED: E3 SUMO-protein ligase NSE2 [Fundu...  NW_012234283.1
# 3   PREDICTED: E3 SUMO-protein ligase NSE2 [Fundu...  NW_012234283.1
# 4   PREDICTED: E3 SUMO-protein ligase NSE2 [Fundu...  NW_012234283.1
#
#                        product    gene     GeneID   transcript_id
# 0  E3 SUMO-protein ligase NSE2  nsmce2  105927720  XM_012864623.2
# 1  E3 SUMO-protein ligase NSE2  nsmce2  110368654  XR_002428266.1
# 2  E3 SUMO-protein ligase NSE2  nsmce2  105927718  XM_012864621.2
# 3  E3 SUMO-protein ligase NSE2  nsmce2  110368655  XR_002428267.1
# 4  E3 SUMO-protein ligase NSE2  nsmce2  105927708  XM_012864610.2
#                      contig           seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN56902_c1_g1_i1  Transcript_160      0  113     113  831490423
# 1  TRINITY_DN56910_c0_g1_i1  Transcript_165      1  140     139  831535516
# 2   TRINITY_DN7043_c0_g1_i1  Transcript_177      0  109     109  831510576
# 3  TRINITY_DN64187_c0_g1_i1  Transcript_240      0  225     225  831501107
# 4  TRINITY_DN64187_c0_g2_i1  Transcript_241      0  187     187  831501107
#
#      NCBI.protein                                              Notes  \
# 0  XP_012706902.1   PREDICTED: cell death activator CIDE-B [Fundu...
# 1  XP_012722638.1   PREDICTED: neuroligin-3-like isoform X2 [Fund...
# 2  XP_012713947.1   PREDICTED: UDP-glucuronosyltransferase 2A1-li...
# 3  XP_012710668.1   PREDICTED: F-box only protein 39 [Fundulus he...
# 4  XP_012710668.1   PREDICTED: F-box only protein 39 [Fundulus he...
#
#   NCBI.trasncript                     NCBI.product          gene  NCBI.gene
# 0  NW_012224604.1      cell death activator CIDE-B         cideb  105916808
# 1  NW_012234309.1     neuroligin-3-like isoform X2  LOC105929411  105929337
# 2  NW_012225612.1  UDP-glucuronosyltransferase 2A1  LOC105922597  105922594
# 3  NW_012224870.1            F-box only protein 39        fbxo39  105919806
# 4  NW_012224870.1            F-box only protein 39        fbxo39  105919806
# (44400, 12)
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (80057, 5)
# Unique Fhet genes: (22455, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100003  gi|831565769|ref|XP_012733144.1| PREDICTED: 60...
# 1  Transcript_100003  gi|831565769|ref|XP_012733144.1| PREDICTED: 60...
# 2  Transcript_100003  gi|831565769|ref|XP_012733144.1| PREDICTED: 60...
# 3  Transcript_100003  gi|831565769|ref|XP_012733144.1| PREDICTED: 60...
# 4  Transcript_100003  gi|831565769|ref|XP_012733144.1| PREDICTED: 60...
#
#    start  end  length         id      protein_id  \
# 0     76   99      23  831565769  XP_012733144.1
# 1     76   99      23  831565769  XP_012733144.1
# 2     76   99      23  831565769  XP_012733144.1
# 3     76   99      23  831565769  XP_012733144.1
# 4     76   99      23  831565769  XP_012733144.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: 60S ribosomal protein L18a [Fundul...  NW_012234461.1
# 1   PREDICTED: 60S ribosomal protein L18a [Fundul...  NW_012234461.1
# 2   PREDICTED: 60S ribosomal protein L18a [Fundul...  NW_012234461.1
# 3   PREDICTED: 60S ribosomal protein L18a [Fundul...  NW_012234461.1
# 4   PREDICTED: 60S ribosomal protein L18a [Fundul...  NW_012234461.1
#
#                       product    gene     GeneID   transcript_id
# 0  60S ribosomal protein L18a  rpl18a  105936707  XM_012877667.2
# 1  60S ribosomal protein L18a  rpl18a  105936713  XM_012877674.2
# 2  60S ribosomal protein L18a  rpl18a  105936738  XM_021324122.1
# 3  60S ribosomal protein L18a  rpl18a  105936732  XM_012877694.2
# 4  60S ribosomal protein L18a  rpl18a  105936731  XM_021324124.1
#                      contig           seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN73275_c0_g1_i1    Transcript_1    117  803     686  831517552
# 1  TRINITY_DN81303_c0_g1_i1   Transcript_97      0   73      73  831503614
# 2   TRINITY_DN7034_c1_g1_i1  Transcript_176     10   77      67  831515782
# 3   TRINITY_DN7043_c0_g1_i1  Transcript_177     12   79      67  831515782
# 4   TRINITY_DN7000_c0_g1_i1  Transcript_180     19   67      48  831514899
#
#      NCBI.protein                                              Notes  \
# 0  XP_012716268.1   PREDICTED: sacsin-like, partial [Fundulus het...
# 1  XP_012711549.1   PREDICTED: salivary acidic proline-rich phosp...
# 2  XP_012715679.1   PREDICTED: tripartite motif-containing protei...
# 3  XP_012715679.1   PREDICTED: tripartite motif-containing protei...
# 4  XP_012715391.1   PREDICTED: tripartite motif-containing protei...
#
#   NCBI.trasncript                                       NCBI.product  \
# 0  NW_012231991.1                                             sacsin
# 1  NW_012224961.1  salivary acidic proline-rich phosphoprotein 1/...
# 2  NW_012227997.1        tripartite motif-containing protein 16-like
# 3  NW_012227997.1        tripartite motif-containing protein 16-like
# 4  NW_012227105.1        tripartite motif-containing protein 16-like
#
#            gene  NCBI.gene
# 0  LOC105925064  105925064
# 1  LOC105920491  105920494
# 2  LOC105924386  105924386
# 3  LOC105924386  105924386
# 4  LOC105924037  105924037
# (45181, 12)
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (82318, 5)
# Unique Fhet genes: (22530, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100003  gi|831547417|ref|XP_012726940.1| PREDICTED: el...
# 1  Transcript_100003  gi|831547417|ref|XP_012726940.1| PREDICTED: el...
# 2  Transcript_100003  gi|831547417|ref|XP_012726940.1| PREDICTED: el...
# 3  Transcript_100003  gi|831547417|ref|XP_012726940.1| PREDICTED: el...
# 4  Transcript_100003  gi|831547417|ref|XP_012726940.1| PREDICTED: el...
#
#    start  end  length         id      protein_id  \
# 0     87  420     333  831547417  XP_012726940.1
# 1     87  420     333  831547417  XP_012726940.1
# 2     87  420     333  831547417  XP_012726940.1
# 3     87  420     333  831547417  XP_012726940.1
# 4     87  420     333  831547417  XP_012726940.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: electron transfer flavoprotein sub...  NW_012234358.1
# 1   PREDICTED: electron transfer flavoprotein sub...  NW_012234358.1
# 2   PREDICTED: electron transfer flavoprotein sub...  NW_012234358.1
# 3   PREDICTED: electron transfer flavoprotein sub...  NW_012234358.1
# 4   PREDICTED: electron transfer flavoprotein sub...  NW_012234358.1
#
#                                              product  gene     GeneID  \
# 0  electron transfer flavoprotein subunit alpha%2...  etfa  105932326
# 1  electron transfer flavoprotein subunit alpha%2...  etfa  105932351
# 2  electron transfer flavoprotein subunit alpha%2...  etfa  110369071
# 3  electron transfer flavoprotein subunit alpha%2...  etfa  105932344
# 4  electron transfer flavoprotein subunit alpha%2...  etfa  105932345
#
#     transcript_id
# 0  XM_012871419.2
# 1  XM_021320958.1
# 2  XR_002428667.1
# 3  XM_012871461.2
# 4  XM_012871464.2
#                      contig          seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN73275_c0_g2_i1   Transcript_2     30  133     103  831573055
# 1  TRINITY_DN73287_c0_g1_i1   Transcript_3     30  180     150  831573058
# 2  TRINITY_DN73227_c0_g1_i1   Transcript_4     30  138     108  831573058
# 3  TRINITY_DN73260_c0_g1_i1   Transcript_5     30  148     118  831573058
# 4  TRINITY_DN73242_c0_g2_i1  Transcript_15      0   68      68  831544836
#
#      NCBI.protein                                              Notes  \
# 0  XP_012735565.1   PREDICTED: bcl-2-modifying factor isoform X1 ...
# 1  XP_012735566.1   PREDICTED: bcl-2-modifying factor isoform X2 ...
# 2  XP_012735566.1   PREDICTED: bcl-2-modifying factor isoform X2 ...
# 3  XP_012735566.1   PREDICTED: bcl-2-modifying factor isoform X2 ...
# 4  XP_012726018.1   PREDICTED: probable G-protein coupled recepto...
#
#   NCBI.trasncript                            NCBI.product          gene  \
# 0  NW_012234514.1       bcl-2-modifying factor isoform X1           bmf
# 1  NW_012234514.1       bcl-2-modifying factor isoform X3           bmf
# 2  NW_012234514.1       bcl-2-modifying factor isoform X3           bmf
# 3  NW_012234514.1       bcl-2-modifying factor isoform X3           bmf
# 4  NW_012234347.1  probable G-protein coupled receptor 61  LOC105931746
#
#    NCBI.gene
# 0  105938397
# 1  105938397
# 2  105938397
# 3  105938397
# 4  105931768
# (46201, 12)
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (68944, 5)
# Unique Fhet genes: (21600, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100060  gi|831567173|ref|XP_012733621.1| PREDICTED: cl...
# 1  Transcript_100060  gi|831567173|ref|XP_012733621.1| PREDICTED: cl...
# 2  Transcript_100060  gi|831567173|ref|XP_012733621.1| PREDICTED: cl...
# 3  Transcript_100060  gi|831567173|ref|XP_012733621.1| PREDICTED: cl...
# 4  Transcript_100060  gi|831567173|ref|XP_012733621.1| PREDICTED: cl...
#
#    start  end  length         id      protein_id  \
# 0    201  537     336  831567173  XP_012733621.1
# 1    201  537     336  831567173  XP_012733621.1
# 2    201  537     336  831567173  XP_012733621.1
# 3    201  537     336  831567173  XP_012733621.1
# 4    201  537     336  831567173  XP_012733621.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: class E basic helix-loop-helix pro...  NW_012234467.1
# 1   PREDICTED: class E basic helix-loop-helix pro...  NW_012234467.1
# 2   PREDICTED: class E basic helix-loop-helix pro...  NW_012234467.1
# 3   PREDICTED: class E basic helix-loop-helix pro...  NW_012234467.1
# 4   PREDICTED: class E basic helix-loop-helix pro...  NW_012234467.1
#
#                                      product          gene     GeneID  \
# 0  class E basic helix-loop-helix protein 40  LOC105937041  105937011
# 1  class E basic helix-loop-helix protein 40  LOC105937041  105937011
# 2  class E basic helix-loop-helix protein 40  LOC105937041  105937044
# 3  class E basic helix-loop-helix protein 40  LOC105937041  105937044
# 4  class E basic helix-loop-helix protein 40  LOC105937041  105937015
#
#     transcript_id
# 0  XM_012878115.2
# 1  XM_012878117.2
# 2  XM_021324358.1
# 3  XM_012878170.2
# 4  XM_021324366.1
#                      contig          seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN73227_c0_g1_i1   Transcript_4     95  576     481  831532028
# 1  TRINITY_DN73257_c0_g1_i1  Transcript_12     49  660     611  831552547
# 2  TRINITY_DN73200_c0_g1_i1  Transcript_13     60  453     393  831552547
# 3  TRINITY_DN73242_c0_g1_i1  Transcript_14     49  273     224  831552547
# 4  TRINITY_DN73242_c0_g2_i1  Transcript_15    102  177      75  831552547
#
#      NCBI.protein                                              Notes  \
# 0  XP_012721397.1   PREDICTED: acidic mammalian chitinase-like [F...
# 1  XP_012728737.1   PREDICTED: vacuolar fusion protein MON1 homol...
# 2  XP_012728737.1   PREDICTED: vacuolar fusion protein MON1 homol...
# 3  XP_012728737.1   PREDICTED: vacuolar fusion protein MON1 homol...
# 4  XP_012728737.1   PREDICTED: vacuolar fusion protein MON1 homol...
#
#   NCBI.trasncript                                       NCBI.product  \
# 0  NW_012234296.1                         acidic mammalian chitinase
# 1  NW_012234382.1  vacuolar fusion protein MON1 homolog B isoform X1
# 2  NW_012234382.1  vacuolar fusion protein MON1 homolog B isoform X1
# 3  NW_012234382.1  vacuolar fusion protein MON1 homolog B isoform X1
# 4  NW_012234382.1  vacuolar fusion protein MON1 homolog B isoform X1
#
#            gene  NCBI.gene
# 0  LOC105928602  105928559
# 1  LOC105933658  105933650
# 2  LOC105933658  105933650
# 3  LOC105933658  105933650
# 4  LOC105933658  105933650
# (38563, 12)
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (75067, 5)
# Unique Fhet genes: (22631, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100003  gi|831567809|ref|XP_012733833.1| PREDICTED: my...
# 1  Transcript_100003  gi|831567809|ref|XP_012733833.1| PREDICTED: my...
# 2  Transcript_100003  gi|831567809|ref|XP_012733833.1| PREDICTED: my...
# 3  Transcript_100003  gi|831567809|ref|XP_012733833.1| PREDICTED: my...
# 4  Transcript_100003  gi|831567809|ref|XP_012733833.1| PREDICTED: my...
#
#    start  end  length         id      protein_id  \
# 0     95  334     239  831567809  XP_012733833.1
# 1     95  334     239  831567809  XP_012733833.1
# 2     95  334     239  831567809  XP_012733833.1
# 3     95  334     239  831567809  XP_012733833.1
# 4     95  334     239  831567809  XP_012733833.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: myozenin-1-like [Fundulus heterocl...  NW_012234473.1
# 1   PREDICTED: myozenin-1-like [Fundulus heterocl...  NW_012234473.1
# 2   PREDICTED: myozenin-1-like [Fundulus heterocl...  NW_012234473.1
# 3   PREDICTED: myozenin-1-like [Fundulus heterocl...  NW_012234473.1
# 4   PREDICTED: myozenin-1-like [Fundulus heterocl...  NW_012234473.1
#
#       product   gene     GeneID   transcript_id
# 0  myozenin-1  myoz1  105937189  XM_021324480.1
# 1  myozenin-1  myoz1  105937192  XM_012878380.2
# 2  myozenin-1  myoz1  105937187  XM_012878376.2
# 3  myozenin-1  myoz1  105937221  XM_012878418.2
# 4  myozenin-1  myoz1  105937212  XM_012878409.2
#                      contig           seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN73205_c0_g1_i1   Transcript_25      0   90      90  831524180
# 1  TRINITY_DN73217_c0_g1_i1   Transcript_27      0   28      28  831580603
# 2  TRINITY_DN81250_c0_g1_i1  Transcript_402     25  315     290  831552443
# 3  TRINITY_DN81282_c0_g1_i1  Transcript_403     25  321     296  831552443
# 4  TRINITY_DN87415_c0_g1_i1  Transcript_404      0  208     208  831552443
#
#      NCBI.protein                                              Notes  \
# 0  XP_012718601.1   PREDICTED: leucine-rich repeat-containing pro...
# 1  XP_012738233.1   PREDICTED: abl interactor 2-like isoform X4 [...
# 2  XP_012728699.1   PREDICTED: toll-like receptor 7 [Fundulus het...
# 3  XP_012728699.1   PREDICTED: toll-like receptor 7 [Fundulus het...
# 4  XP_012728699.1   PREDICTED: toll-like receptor 7 [Fundulus het...
#
#   NCBI.trasncript                                    NCBI.product  \
# 0  NW_012234271.1  leucine-rich repeat-containing protein 4B-like
# 1  NW_012234577.1                abl interactor 2-like isoform X7
# 2  NW_012234381.1                            toll-like receptor 7
# 3  NW_012234381.1                            toll-like receptor 7
# 4  NW_012234381.1                            toll-like receptor 7
#
#            gene  NCBI.gene
# 0  LOC105926720  105926618
# 1  LOC105940289  105940270
# 2  LOC105933632  105933587
# 3  LOC105933632  105933587
# 4  LOC105933632  105933587
# (42091, 12)
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (41837, 5)
# Unique Fhet genes: (18280, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100003  gi|831483713|ref|XP_012735550.1| PREDICTED: FR...
# 1  Transcript_100003  gi|831483713|ref|XP_012735550.1| PREDICTED: FR...
# 2  Transcript_100003  gi|831483713|ref|XP_012735550.1| PREDICTED: FR...
# 3  Transcript_100003  gi|831483713|ref|XP_012735550.1| PREDICTED: FR...
# 4  Transcript_100003  gi|831483713|ref|XP_012735550.1| PREDICTED: FR...
#
#    start  end  length         id      protein_id  \
# 0      0  424     424  831483713  XP_012735550.1
# 1      0  424     424  831483713  XP_012735550.1
# 2      0  424     424  831483713  XP_012735550.1
# 3      0  424     424  831483713  XP_012735550.1
# 4      0  424     424  831483713  XP_012735550.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: FRAS1-related extracellular matrix...  NW_012224496.1
# 1   PREDICTED: FRAS1-related extracellular matrix...  NW_012224496.1
# 2   PREDICTED: FRAS1-related extracellular matrix...  NW_012224496.1
# 3   PREDICTED: FRAS1-related extracellular matrix...  NW_012224496.1
# 4   PREDICTED: FRAS1-related extracellular matrix...  NW_012224496.1
#
#                                              product   gene     GeneID  \
# 0  FRAS1-related extracellular matrix protein 1 i...  frem1  105938378
# 1  FRAS1-related extracellular matrix protein 1 i...  frem1  105938378
# 2  FRAS1-related extracellular matrix protein 1 i...  frem1  105938324
# 3  FRAS1-related extracellular matrix protein 1 i...  frem1  105938388
# 4  FRAS1-related extracellular matrix protein 1 i...  frem1  105938401
#
#     transcript_id
# 0  XM_021307220.1
# 1  XM_012880096.2
# 2  XM_012880025.1
# 3  XM_012880107.2
# 4  XM_012880136.2
#                      contig          seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN73240_c0_g1_i1  Transcript_16     37  355     318  831482748
# 1  TRINITY_DN32561_c0_g1_i1  Transcript_34    327  557     230  831543115
# 2  TRINITY_DN32542_c0_g1_i1  Transcript_43     54  376     322  831523103
# 3  TRINITY_DN32516_c0_g1_i1  Transcript_46     20  400     380  831580562
# 4  TRINITY_DN32505_c0_g1_i1  Transcript_47    131  750     619  831580562
#
#      NCBI.protein                                              Notes  \
# 0  XP_012732171.1   PREDICTED: deoxyribose-phosphate aldolase [Fu...
# 1  XP_012725411.1   PREDICTED: ephrin-A5 isoform X1 [Fundulus het...
# 2  XP_012718222.1   PREDICTED: leucine-rich repeat-containing pro...
# 3  XP_012738220.1       PREDICTED: plastin-2 [Fundulus heteroclitus]
# 4  XP_012738220.1       PREDICTED: plastin-2 [Fundulus heteroclitus]
#
#   NCBI.trasncript                               NCBI.product    gene  \
# 0  NW_012224481.1             deoxyribose-phosphate aldolase    dera
# 1  NW_012234342.1                                  ephrin-A5   efna5
# 2  NW_012234268.1  leucine-rich repeat-containing protein 59  lrrc59
# 3  NW_012234577.1                                  plastin-2    lcp1
# 4  NW_012234577.1                                  plastin-2    lcp1
#
#    NCBI.gene
# 0  105935912
# 1  105931302
# 2  105926418
# 3  105940270
# 4  105940270
# (23974, 12)
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (94672, 5)
# Unique Fhet genes: (24275, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100075  gi|831498985|ref|XP_012709928.1| PREDICTED: tr...
# 1  Transcript_100075  gi|831498985|ref|XP_012709928.1| PREDICTED: tr...
# 2  Transcript_100075  gi|831498985|ref|XP_012709928.1| PREDICTED: tr...
# 3  Transcript_100075  gi|831498985|ref|XP_012709928.1| PREDICTED: tr...
# 4  Transcript_100075  gi|831498985|ref|XP_012709928.1| PREDICTED: tr...
#
#    start  end  length         id      protein_id  \
# 0     23  176     153  831498985  XP_012709928.1
# 1     23  176     153  831498985  XP_012709928.1
# 2     23  176     153  831498985  XP_012709928.1
# 3     23  176     153  831498985  XP_012709928.1
# 4     23  176     153  831498985  XP_012709928.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: triadin-like isoform X2 [Fundulus ...  NW_012224807.1
# 1   PREDICTED: triadin-like isoform X2 [Fundulus ...  NW_012224807.1
# 2   PREDICTED: triadin-like isoform X2 [Fundulus ...  NW_012224807.1
# 3   PREDICTED: triadin-like isoform X2 [Fundulus ...  NW_012224807.1
# 4   PREDICTED: triadin-like isoform X2 [Fundulus ...  NW_012224807.1
#
#                    product          gene     GeneID   transcript_id
# 0  triadin-like isoform X2  LOC105919208  105919208  XM_021311673.1
# 1  triadin-like isoform X2  LOC105919208  105919208  XM_012854473.2
# 2  triadin-like isoform X2  LOC105919208  105919208  XM_012854476.2
# 3  triadin-like isoform X2  LOC105919208  105919208  XM_012854474.2
# 4  triadin-like isoform X2  LOC105919208  105919208  XM_012854477.2
#                      contig          seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN32550_c0_g1_i1  Transcript_49     18  160     142  831525402
# 1  TRINITY_DN32535_c0_g1_i1  Transcript_51     21  467     446  831525402
# 2  TRINITY_DN32523_c0_g1_i1  Transcript_52     62  328     266  831525402
# 3  TRINITY_DN32599_c0_g1_i1  Transcript_54     62  299     237  831525402
# 4  TRINITY_DN32524_c0_g1_i1  Transcript_57      0  263     263  831525402
#
#      NCBI.protein                                              Notes  \
# 0  XP_012719037.1   PREDICTED: serine/threonine-protein kinase RI...
# 1  XP_012719037.1   PREDICTED: serine/threonine-protein kinase RI...
# 2  XP_012719037.1   PREDICTED: serine/threonine-protein kinase RI...
# 3  XP_012719037.1   PREDICTED: serine/threonine-protein kinase RI...
# 4  XP_012719037.1   PREDICTED: serine/threonine-protein kinase RI...
#
#   NCBI.trasncript                          NCBI.product   gene  NCBI.gene
# 0  NW_012234274.1  serine/threonine-protein kinase RIO2  riok2  105926901
# 1  NW_012234274.1  serine/threonine-protein kinase RIO2  riok2  105926901
# 2  NW_012234274.1  serine/threonine-protein kinase RIO2  riok2  105926901
# 3  NW_012234274.1  serine/threonine-protein kinase RIO2  riok2  105926901
# 4  NW_012234274.1  serine/threonine-protein kinase RIO2  riok2  105926901
# (37227, 12)
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (63254, 5)
# Unique Fhet genes: (21624, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100002  gi|831530264|ref|XP_012720768.1| PREDICTED: ST...
# 1  Transcript_100002  gi|831530264|ref|XP_012720768.1| PREDICTED: ST...
# 2  Transcript_100002  gi|831530264|ref|XP_012720768.1| PREDICTED: ST...
# 3  Transcript_100002  gi|831530264|ref|XP_012720768.1| PREDICTED: ST...
# 4  Transcript_100002  gi|831530264|ref|XP_012720768.1| PREDICTED: ST...
#
#    start  end  length         id      protein_id  \
# 0     11  151     140  831530264  XP_012720768.1
# 1     11  151     140  831530264  XP_012720768.1
# 2     11  151     140  831530264  XP_012720768.1
# 3     11  151     140  831530264  XP_012720768.1
# 4     11  151     140  831530264  XP_012720768.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: STAM-binding protein [Fundulus het...  NW_012234291.1
# 1   PREDICTED: STAM-binding protein [Fundulus het...  NW_012234291.1
# 2   PREDICTED: STAM-binding protein [Fundulus het...  NW_012234291.1
# 3   PREDICTED: STAM-binding protein [Fundulus het...  NW_012234291.1
# 4   PREDICTED: STAM-binding protein [Fundulus het...  NW_012234291.1
#
#                 product    gene     GeneID   transcript_id
# 0  STAM-binding protein  stambp  105928165  XR_001166324.2
# 1  STAM-binding protein  stambp  105928165  XR_002428305.1
# 2  STAM-binding protein  stambp  105928165  XM_021317915.1
# 3  STAM-binding protein  stambp  105928165  XM_012865301.2
# 4  STAM-binding protein  stambp  105928165  XM_012865302.2
#                      contig           seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN32549_c0_g1_i1   Transcript_82     50  228     178  831555246
# 1  TRINITY_DN81321_c1_g1_i1  Transcript_107     13  193     180  831517887
# 2  TRINITY_DN81374_c0_g1_i1  Transcript_108      0  172     172  831517887
# 3   TRINITY_DN7003_c0_g1_i1  Transcript_179      0  156     156  831544190
# 4  TRINITY_DN64187_c0_g2_i1  Transcript_241     35  316     281  831570358
#
#      NCBI.protein                                              Notes  \
# 0  XP_012729643.1   PREDICTED: tubulin polymerization-promoting p...
# 1  XP_012716379.1   PREDICTED: alpha-2-HS-glycoprotein-like [Fund...
# 2  XP_012716379.1   PREDICTED: alpha-2-HS-glycoprotein-like [Fund...
# 3  XP_012725788.1   PREDICTED: uncharacterized protein LOC1059315...
# 4  XP_012734689.1   PREDICTED: RNA/RNP complex-1-interacting phos...
#
#   NCBI.trasncript                                       NCBI.product  \
# 0  NW_012234398.1  tubulin polymerization-promoting protein famil...
# 1  NW_012234254.1                            alpha-2-HS-glycoprotein
# 2  NW_012234254.1                            alpha-2-HS-glycoprotein
# 3  NW_012234344.1    uncharacterized protein LOC105931591 isoform X1
# 4  NW_012234493.1  RNA/RNP complex-1-interacting phosphatase-like...
#
#            gene  NCBI.gene
# 0  LOC105934278  105934258
# 1  LOC105925199  105925170
# 2  LOC105925199  105925170
# 3  LOC105931591  105931550
# 4  LOC105937751  105937761
# (35049, 12)
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (73458, 5)
# Unique Fhet genes: (21806, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100005  gi|831543230|ref|XP_012725447.1| PREDICTED: F-...
# 1  Transcript_100005  gi|831543230|ref|XP_012725447.1| PREDICTED: F-...
# 2  Transcript_100005  gi|831543230|ref|XP_012725447.1| PREDICTED: F-...
# 3  Transcript_100005  gi|831543230|ref|XP_012725447.1| PREDICTED: F-...
# 4  Transcript_100005  gi|831543230|ref|XP_012725447.1| PREDICTED: F-...
#
#    start  end  length         id      protein_id  \
# 0      0  650     650  831543230  XP_012725447.1
# 1      0  650     650  831543230  XP_012725447.1
# 2      0  650     650  831543230  XP_012725447.1
# 3      0  650     650  831543230  XP_012725447.1
# 4      0  650     650  831543230  XP_012725447.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: F-box/LRR-repeat protein 17 [Fundu...  NW_012234342.1
# 1   PREDICTED: F-box/LRR-repeat protein 17 [Fundu...  NW_012234342.1
# 2   PREDICTED: F-box/LRR-repeat protein 17 [Fundu...  NW_012234342.1
# 3   PREDICTED: F-box/LRR-repeat protein 17 [Fundu...  NW_012234342.1
# 4   PREDICTED: F-box/LRR-repeat protein 17 [Fundu...  NW_012234342.1
#
#                        product    gene     GeneID   transcript_id
# 0  F-box/LRR-repeat protein 17  fbxl17  105931302  XM_012869928.2
# 1  F-box/LRR-repeat protein 17  fbxl17  105931348  XM_021320235.1
# 2  F-box/LRR-repeat protein 17  fbxl17  105931348  XM_012869982.2
# 3  F-box/LRR-repeat protein 17  fbxl17  105931303  XM_021320228.1
# 4  F-box/LRR-repeat protein 17  fbxl17  105931344  XM_012869974.2
#                      contig           seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN73209_c0_g1_i1   Transcript_26      0   66      66  831534962
# 1  TRINITY_DN73217_c0_g1_i1   Transcript_27      0   51      51  831534962
# 2  TRINITY_DN32550_c0_g1_i1   Transcript_49      0   21      21  831522803
# 3  TRINITY_DN81321_c1_g1_i1  Transcript_107      1   91      90  831493469
# 4  TRINITY_DN81390_c0_g1_i1  Transcript_113     18  125     107  831473992
#
#      NCBI.protein                                              Notes  \
# 0  XP_012722439.1   PREDICTED: basement membrane-specific heparan...
# 1  XP_012722439.1   PREDICTED: basement membrane-specific heparan...
# 2  XP_012718119.1   PREDICTED: chromobox protein homolog 3-like i...
# 3  XP_012707969.1   PREDICTED: cAMP-specific 3',5'-cyclic phospho...
# 4  XP_012717323.1   PREDICTED: glutamate receptor 3 isoform X3 [F...
#
#   NCBI.trasncript                                       NCBI.product  \
# 0  NW_012234307.1  basement membrane-specific heparan sulfate pro...
# 1  NW_012234307.1  basement membrane-specific heparan sulfate pro...
# 2  NW_012234267.1             chromobox protein homolog 3 isoform X1
# 3  NW_012224662.1  cAMP-specific 3'%2C5'-cyclic phosphodiesterase...
# 4  NW_012224401.1                    glutamate receptor 3 isoform X3
#
#            gene  NCBI.gene
# 0  LOC105929277  105929256
# 1  LOC105929277  105929256
# 2  LOC105926367  105926280
# 3  LOC105917643  105917640
# 4  LOC105925698  105920463
# (41755, 12)
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (62852, 5)
# Unique Fhet genes: (20647, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100015  gi|831480331|ref|XP_012723558.1| PREDICTED: cy...
# 1  Transcript_100015  gi|831480331|ref|XP_012723558.1| PREDICTED: cy...
# 2  Transcript_100015  gi|831480331|ref|XP_012723558.1| PREDICTED: cy...
# 3  Transcript_100015  gi|831480331|ref|XP_012723558.1| PREDICTED: cy...
# 4  Transcript_100015  gi|831480331|ref|XP_012723558.1| PREDICTED: cy...
#
#    start  end  length         id      protein_id  \
# 0     19  478     459  831480331  XP_012723558.1
# 1     19  478     459  831480331  XP_012723558.1
# 2     19  478     459  831480331  XP_012723558.1
# 3     19  478     459  831480331  XP_012723558.1
# 4     19  478     459  831480331  XP_012723558.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: cytochrome b-c1 complex subunit 2,...  NW_012224459.1
# 1   PREDICTED: cytochrome b-c1 complex subunit 2,...  NW_012224459.1
# 2   PREDICTED: cytochrome b-c1 complex subunit 2,...  NW_012224459.1
# 3   PREDICTED: cytochrome b-c1 complex subunit 2,...  NW_012224459.1
# 4   PREDICTED: cytochrome b-c1 complex subunit 2,...  NW_012224459.1
#
#                                              product          gene     GeneID  \
# 0  cytochrome b-c1 complex subunit 2%2C mitochond...  LOC105930091  105929961
# 1  cytochrome b-c1 complex subunit 2%2C mitochond...  LOC105930091  105929948
# 2  cytochrome b-c1 complex subunit 2%2C mitochond...  LOC105930091  105929948
# 3  cytochrome b-c1 complex subunit 2%2C mitochond...  LOC105930091  105929948
# 4  cytochrome b-c1 complex subunit 2%2C mitochond...  LOC105930091  105929948
#
#     transcript_id
# 0  XM_021319363.1
# 1  XM_021319344.1
# 2  XM_021319339.1
# 3  XM_021319355.1
# 4  XM_021319349.1
#                      contig           seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN32517_c0_g2_i1   Transcript_40      5   78      73  831484161
# 1  TRINITY_DN56987_c0_g1_i1  Transcript_166      0   75      75  831536829
# 2   TRINITY_DN7001_c0_g1_i1  Transcript_187      0   66      66  831491733
# 3  TRINITY_DN48699_c0_g1_i1  Transcript_217      0   76      76  831523926
# 4  TRINITY_DN48605_c0_g1_i1  Transcript_235     37   77      40  831529475
#
#      NCBI.protein                                              Notes  \
# 0  XP_012737200.1   PREDICTED: calmodulin-regulated spectrin-asso...
# 1  XP_012723102.1   PREDICTED: endophilin-A3 [Fundulus heteroclitus]
# 2  XP_012707359.1   PREDICTED: GTP-binding protein REM 2 [Fundulu...
# 3  XP_012718509.1   PREDICTED: heparan sulfate glucosamine 3-O-su...
# 4  XP_012720487.1   PREDICTED: serine/arginine repetitive matrix ...
#
#   NCBI.trasncript                                       NCBI.product  \
# 0  NW_012224503.1  calmodulin-regulated spectrin-associated prote...
# 1  NW_012234311.1                           endophilin-A3 isoform X1
# 2  NW_012224629.1                          GTP-binding protein REM 2
# 3  NW_012234271.1  heparan sulfate glucosamine 3-O-sulfotransfera...
# 4  NW_012234288.1        serine/arginine repetitive matrix protein 3
#
#            gene  NCBI.gene
# 0  LOC105939518  105939452
# 1  LOC105929749  105929642
# 2  LOC105917180  105917174
# 3  LOC105926660  105926618
# 4         srrm3  105927980
# (35861, 12)
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (81920, 5)
# Unique Fhet genes: (22718, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100003  gi|831474071|ref|XP_012719905.1| PREDICTED: PD...
# 1  Transcript_100003  gi|831474071|ref|XP_012719905.1| PREDICTED: PD...
# 2  Transcript_100003  gi|831474071|ref|XP_012719905.1| PREDICTED: PD...
# 3  Transcript_100003  gi|831474071|ref|XP_012719905.1| PREDICTED: PD...
# 4  Transcript_100003  gi|831474071|ref|XP_012719905.1| PREDICTED: PD...
#
#    start  end  length         id      protein_id  \
# 0      0  153     153  831474071  XP_012719905.1
# 1      0  153     153  831474071  XP_012719905.1
# 2      0  153     153  831474071  XP_012719905.1
# 3      0  153     153  831474071  XP_012719905.1
# 4      0  153     153  831474071  XP_012719905.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: PDZ and LIM domain protein 7 isofo...  NW_012224401.1
# 1   PREDICTED: PDZ and LIM domain protein 7 isofo...  NW_012224401.1
# 2   PREDICTED: PDZ and LIM domain protein 7 isofo...  NW_012224401.1
# 3   PREDICTED: PDZ and LIM domain protein 7 isofo...  NW_012224401.1
# 4   PREDICTED: PDZ and LIM domain protein 7 isofo...  NW_012224401.1
#
#                                    product    gene     GeneID   transcript_id
# 0  PDZ and LIM domain protein 7 isoform X2  pdlim7  105920463  XM_012856390.2
# 1  PDZ and LIM domain protein 7 isoform X2  pdlim7  105915213  XM_021321288.1
# 2  PDZ and LIM domain protein 7 isoform X2  pdlim7  105915271  XM_012849362.2
# 3  PDZ and LIM domain protein 7 isoform X2  pdlim7  105915271  XM_012849437.2
# 4  PDZ and LIM domain protein 7 isoform X2  pdlim7  105915419  XM_021323826.1
#                      contig           seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN32564_c0_g1_i1   Transcript_44      0  120     120  831500865
# 1  TRINITY_DN48652_c0_g1_i1  Transcript_203     21   68      47  831488241
# 2  TRINITY_DN48646_c0_g1_i1  Transcript_207     51  388     337  831484967
# 3  TRINITY_DN23110_c0_g1_i1  Transcript_282      0   93      93  831542339
# 4  TRINITY_DN23122_c0_g1_i1  Transcript_317     35   87      52  831550128
#
#      NCBI.protein                                              Notes  \
# 0  XP_012710584.1   PREDICTED: UPF0606 protein KIAA1549L homolog ...
# 1  XP_012706118.1   PREDICTED: transmembrane protein 178B-like [F...
# 2  XP_012704904.1   PREDICTED: uncharacterized protein LOC1059153...
# 3  XP_012725041.1   PREDICTED: corticotropin-releasing factor-bin...
# 4  XP_012727885.1   PREDICTED: synapse differentiation-inducing g...
#
#   NCBI.trasncript                                       NCBI.product  \
# 0  NW_012224869.1       UPF0606 protein KIAA1549L homolog isoform X1
# 1  NW_012224574.1                    transmembrane protein 178B-like
# 2  NW_012224519.1               uncharacterized protein LOC105915370
# 3  NW_012234337.1     corticotropin-releasing factor-binding protein
# 4  NW_012234371.1  synapse differentiation-inducing gene protein ...
#
#            gene  NCBI.gene
# 0     kiaa1549l  105919702
# 1  LOC105916264  105916268
# 2  LOC105915370  105915372
# 3         crhbp  110368956
# 4  LOC105933059  105933072
# (44176, 12)
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (74555, 5)
# Unique Fhet genes: (22338, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100000  gi|831539324|ref|XP_012723974.1| PREDICTED: ad...
# 1  Transcript_100000  gi|831539324|ref|XP_012723974.1| PREDICTED: ad...
# 2  Transcript_100000  gi|831539324|ref|XP_012723974.1| PREDICTED: ad...
# 3  Transcript_100000  gi|831539324|ref|XP_012723974.1| PREDICTED: ad...
# 4  Transcript_100000  gi|831539324|ref|XP_012723974.1| PREDICTED: ad...
#
#    start  end  length         id      protein_id  \
# 0     73  132      59  831539324  XP_012723974.1
# 1     73  132      59  831539324  XP_012723974.1
# 2     73  132      59  831539324  XP_012723974.1
# 3     73  132      59  831539324  XP_012723974.1
# 4     73  132      59  831539324  XP_012723974.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: adenylate cyclase type 5 isoform X...  NW_012234322.1
# 1   PREDICTED: adenylate cyclase type 5 isoform X...  NW_012234322.1
# 2   PREDICTED: adenylate cyclase type 5 isoform X...  NW_012234322.1
# 3   PREDICTED: adenylate cyclase type 5 isoform X...  NW_012234322.1
# 4   PREDICTED: adenylate cyclase type 5 isoform X...  NW_012234322.1
#
#                                product   gene     GeneID   transcript_id
# 0  adenylate cyclase type 5 isoform X2  adcy5  105930348  XM_021319478.1
# 1  adenylate cyclase type 5 isoform X2  adcy5  105930315  XM_021319473.1
# 2  adenylate cyclase type 5 isoform X2  adcy5  105930314  XM_012868460.2
# 3  adenylate cyclase type 5 isoform X2  adcy5  105930335  XM_012868512.2
# 4  adenylate cyclase type 5 isoform X2  adcy5  105930335  XM_012868510.2
#                      contig           seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN56913_c0_g1_i1  Transcript_116     61   83      22  831573625
# 1   TRINITY_DN7039_c0_g1_i1  Transcript_178     33   69      36  831578823
# 2   TRINITY_DN7003_c0_g1_i1  Transcript_179     33   67      34  831578823
# 3   TRINITY_DN7063_c0_g2_i1  Transcript_184      0   88      88  831519976
# 4  TRINITY_DN48670_c0_g1_i1  Transcript_227     61   91      30  831513323
#
#      NCBI.protein                                              Notes  \
# 0  XP_012735765.1   PREDICTED: pleckstrin homology domain-contain...
# 1  XP_012737611.1   PREDICTED: zinc finger and BTB domain-contain...
# 2  XP_012737611.1   PREDICTED: zinc finger and BTB domain-contain...
# 3  XP_012717112.1   PREDICTED: teashirt homolog 3 [Fundulus heter...
# 4  XP_012714877.1   PREDICTED: dynein assembly factor with WDR re...
#
#   NCBI.trasncript                                       NCBI.product  \
# 0  NW_012234517.1  pleckstrin homology domain-containing family A...
# 1  NW_012234559.1  zinc finger and BTB domain-containing protein ...
# 2  NW_012234559.1  zinc finger and BTB domain-containing protein ...
# 3  NW_012234259.1                                 teashirt homolog 3
# 4  NW_012226213.1  dynein assembly factor with WDR repeat domains...
#
#            gene  NCBI.gene
# 0  LOC105938538  105938477
# 1  LOC105939840  105939850
# 2  LOC105939840  105939850
# 3         tshz3  105925649
# 4          daw1  105923370
# (40219, 12)
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (78820, 5)
# Unique Fhet genes: (22849, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100000  gi|831558983|ref|XP_012730895.1| PREDICTED: or...
# 1  Transcript_100000  gi|831558983|ref|XP_012730895.1| PREDICTED: or...
# 2  Transcript_100000  gi|831558983|ref|XP_012730895.1| PREDICTED: or...
# 3  Transcript_100000  gi|831558983|ref|XP_012730895.1| PREDICTED: or...
# 4  Transcript_100000  gi|831558983|ref|XP_012730895.1| PREDICTED: or...
#
#    start  end  length         id      protein_id  \
# 0     51  517     466  831558983  XP_012730895.1
# 1     51  517     466  831558983  XP_012730895.1
# 2     51  517     466  831558983  XP_012730895.1
# 3     51  517     466  831558983  XP_012730895.1
# 4     51  517     466  831558983  XP_012730895.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: origin recognition complex subunit...  NW_012234418.1
# 1   PREDICTED: origin recognition complex subunit...  NW_012234418.1
# 2   PREDICTED: origin recognition complex subunit...  NW_012234418.1
# 3   PREDICTED: origin recognition complex subunit...  NW_012234418.1
# 4   PREDICTED: origin recognition complex subunit...  NW_012234418.1
#
#                                      product          gene     GeneID  \
# 0  origin recognition complex subunit 4-like  LOC105935160  105935146
# 1  origin recognition complex subunit 4-like  LOC105935160  105935083
# 2  origin recognition complex subunit 4-like  LOC105935160  105935132
# 3  origin recognition complex subunit 4-like  LOC105935160  105935132
# 4  origin recognition complex subunit 4-like  LOC105935160  105935157
#
#     transcript_id
# 0  XM_021323008.1
# 1  XM_012875310.2
# 2  XM_021322934.1
# 3  XM_012875401.2
# 4  XM_012875436.2
#                      contig           seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN73227_c0_g1_i1    Transcript_4      0  178     178  831554879
# 1  TRINITY_DN73216_c0_g1_i1   Transcript_29     36   75      39  831570279
# 2  TRINITY_DN32566_c0_g1_i1   Transcript_30      0  130     130  831570279
# 3  TRINITY_DN81374_c0_g1_i1  Transcript_108      0   68      68  831551401
# 4  TRINITY_DN81374_c1_g1_i1  Transcript_109      0   72      72  831551401
#
#      NCBI.protein                                              Notes  \
# 0  XP_012729519.1   PREDICTED: G protein-activated inward rectifi...
# 1  XP_012734659.1   PREDICTED: snRNA-activating protein complex s...
# 2  XP_012734659.1   PREDICTED: snRNA-activating protein complex s...
# 3  XP_012728336.1   PREDICTED: POU domain, class 3, transcription...
# 4  XP_012728336.1   PREDICTED: POU domain, class 3, transcription...
#
#   NCBI.trasncript                                       NCBI.product  \
# 0  NW_012234395.1  G protein-activated inward rectifier potassium...
# 1  NW_012234492.1    snRNA-activating protein complex subunit 1-like
# 2  NW_012234492.1    snRNA-activating protein complex subunit 1-like
# 3  NW_012234377.1    POU domain%2C class 3%2C transcription factor 2
# 4  NW_012234377.1    POU domain%2C class 3%2C transcription factor 2
#
#            gene  NCBI.gene
# 0         kcnj3  105934158
# 1  LOC105937725  105937719
# 2  LOC105937725  105937719
# 3        pou3f2  105933429
# 4        pou3f2  105933429
# (33424, 12)
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (73426, 5)
# Unique Fhet genes: (22601, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100000  gi|831537298|ref|XP_012723266.1| PREDICTED: un...
# 1  Transcript_100000  gi|831537298|ref|XP_012723266.1| PREDICTED: un...
# 2  Transcript_100000  gi|831537298|ref|XP_012723266.1| PREDICTED: un...
# 3  Transcript_100000  gi|831537298|ref|XP_012723266.1| PREDICTED: un...
# 4  Transcript_100000  gi|831537298|ref|XP_012723266.1| PREDICTED: un...
#
#    start  end  length         id      protein_id  \
# 0      0  130     130  831537298  XP_012723266.1
# 1      0  130     130  831537298  XP_012723266.1
# 2      0  130     130  831537298  XP_012723266.1
# 3      0  130     130  831537298  XP_012723266.1
# 4      0  130     130  831537298  XP_012723266.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: unconventional myosin-VI-like isof...  NW_012234314.1
# 1   PREDICTED: unconventional myosin-VI-like isof...  NW_012234314.1
# 2   PREDICTED: unconventional myosin-VI-like isof...  NW_012234314.1
# 3   PREDICTED: unconventional myosin-VI-like isof...  NW_012234314.1
# 4   PREDICTED: unconventional myosin-VI-like isof...  NW_012234314.1
#
#                                     product          gene     GeneID  \
# 0  unconventional myosin-VI-like isoform X4  LOC105929881  105929877
# 1  unconventional myosin-VI-like isoform X4  LOC105929881  105929877
# 2  unconventional myosin-VI-like isoform X4  LOC105929881  105929877
# 3  unconventional myosin-VI-like isoform X4  LOC105929881  105929875
# 4  unconventional myosin-VI-like isoform X4  LOC105929881  105929876
#
#     transcript_id
# 0  XM_021319148.1
# 1  XM_021319149.1
# 2  XM_021319147.1
# 3  XM_012867799.2
# 4  XM_012867801.2
#                      contig           seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN32550_c0_g1_i1   Transcript_49      1  206     205  831545408
# 1  TRINITY_DN32550_c0_g2_i1   Transcript_50      0  172     172  831538787
# 2  TRINITY_DN32577_c0_g1_i1   Transcript_63      0   55      55  831503985
# 3  TRINITY_DN67518_c1_g1_i1  Transcript_357      0  138     138  831528929
# 4  TRINITY_DN87446_c0_g1_i1  Transcript_407     47  211     164  831520549
#
#      NCBI.protein                                              Notes  \
# 0  XP_012726222.1   PREDICTED: photoreceptor-specific nuclear rec...
# 1  XP_012723788.1   PREDICTED: protocadherin-8 [Fundulus heterocl...
# 2  XP_012711686.1   PREDICTED: solute carrier family 13 member 5-...
# 3  XP_012720290.1   PREDICTED: choline transporter-like protein 5...
# 4  XP_012717313.1   PREDICTED: UDP-N-acetylglucosamine transferas...
#
#   NCBI.trasncript                                       NCBI.product  \
# 0  NW_012234349.1       photoreceptor-specific nuclear receptor-like
# 1  NW_012234321.1                                    protocadherin-8
# 2  NW_012224983.1       solute carrier family 13 member 5 isoform X1
# 3  NW_012234285.1      choline transporter-like protein 5 isoform X1
# 4  NW_012234260.1  UDP-N-acetylglucosamine transferase subunit AL...
#
#            gene  NCBI.gene
# 0  LOC105931886  105931902
# 1         pcdh8  105930227
# 2  LOC105920619  105920616
# 3       slc44a5  110368665
# 4  LOC105925823  105925704
# (41184, 12)
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (57035, 5)
# Unique Fhet genes: (20439, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100002  gi|831552584|ref|XP_012728750.1| PREDICTED: ep...
# 1  Transcript_100002  gi|831552584|ref|XP_012728750.1| PREDICTED: ep...
# 2  Transcript_100002  gi|831552584|ref|XP_012728750.1| PREDICTED: ep...
# 3  Transcript_100002  gi|831552584|ref|XP_012728750.1| PREDICTED: ep...
# 4  Transcript_100002  gi|831552584|ref|XP_012728750.1| PREDICTED: ep...
#
#    start  end  length         id      protein_id  \
# 0     37  983     946  831552584  XP_012728750.1
# 1     37  983     946  831552584  XP_012728750.1
# 2     37  983     946  831552584  XP_012728750.1
# 3     37  983     946  831552584  XP_012728750.1
# 4     37  983     946  831552584  XP_012728750.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: ephrin type-A receptor 2-like [Fun...  NW_012234382.1
# 1   PREDICTED: ephrin type-A receptor 2-like [Fun...  NW_012234382.1
# 2   PREDICTED: ephrin type-A receptor 2-like [Fun...  NW_012234382.1
# 3   PREDICTED: ephrin type-A receptor 2-like [Fun...  NW_012234382.1
# 4   PREDICTED: ephrin type-A receptor 2-like [Fun...  NW_012234382.1
#
#                          product          gene     GeneID   transcript_id
# 0  ephrin type-A receptor 2-like  LOC105933666  105933650  XM_021321885.1
# 1  ephrin type-A receptor 2-like  LOC105933666  105933677  XM_021321925.1
# 2  ephrin type-A receptor 2-like  LOC105933666  105933677  XM_021321926.1
# 3  ephrin type-A receptor 2-like  LOC105933666  105933651  XM_021321927.1
# 4  ephrin type-A receptor 2-like  LOC105933666  105933681  XM_021321902.1
#                      contig           seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN32573_c0_g1_i1   Transcript_71      0  116     116  831571436
# 1  TRINITY_DN32562_c1_g1_i1   Transcript_74      0   68      68  831492447
# 2  TRINITY_DN32582_c0_g1_i1   Transcript_85     16   44      28  831529266
# 3  TRINITY_DN56926_c1_g1_i1  Transcript_140      0   61      61  831497728
# 4  TRINITY_DN56984_c0_g2_i1  Transcript_152      0   23      23  831564224
#
#      NCBI.protein                                              Notes  \
# 0  XP_012735038.1   PREDICTED: protocadherin-16-like [Fundulus he...
# 1  XP_012707613.1   PREDICTED: ankyrin repeat domain-containing p...
# 2  XP_012720412.1   PREDICTED: calmodulin-lysine N-methyltransfer...
# 3  XP_012709481.1   PREDICTED: nuclear receptor ROR-alpha-like is...
# 4  XP_012732631.1   PREDICTED: taste receptor type 1 member 1 [Fu...
#
#   NCBI.trasncript                                       NCBI.product  \
# 0  NW_012234501.1                              protocadherin-16-like
# 1  NW_012224642.1  ankyrin repeat domain-containing protein 34B-like
# 2  NW_012234287.1              calmodulin-lysine N-methyltransferase
# 3  NW_012224770.1         nuclear receptor ROR-alpha-like isoform X1
# 4  NW_012234452.1                     taste receptor type 1 member 2
#
#            gene  NCBI.gene
# 0  LOC105937994  105937982
# 1  LOC105917370  105917366
# 2        camkmt  105927939
# 3  LOC105918865  110367056
# 4        tas1r2  105936411
# (32741, 12)
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (54836, 5)
# Unique Fhet genes: (20382, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100001  gi|831492530|ref|XP_012707644.1| PREDICTED: ex...
# 1  Transcript_100001  gi|831492530|ref|XP_012707644.1| PREDICTED: ex...
# 2  Transcript_100001  gi|831492530|ref|XP_012707644.1| PREDICTED: ex...
# 3  Transcript_100001  gi|831492530|ref|XP_012707644.1| PREDICTED: ex...
# 4  Transcript_100001  gi|831492530|ref|XP_012707644.1| PREDICTED: ex...
#
#    start  end  length         id      protein_id  \
# 0     63   95      32  831492530  XP_012707644.1
# 1     63   95      32  831492530  XP_012707644.1
# 2     63   95      32  831492530  XP_012707644.1
# 3     63   95      32  831492530  XP_012707644.1
# 4     63   95      32  831492530  XP_012707644.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: exostosin-1c-like [Fundulus hetero...  NW_012224643.1
# 1   PREDICTED: exostosin-1c-like [Fundulus hetero...  NW_012224643.1
# 2   PREDICTED: exostosin-1c-like [Fundulus hetero...  NW_012224643.1
# 3   PREDICTED: exostosin-1c-like [Fundulus hetero...  NW_012224643.1
# 4   PREDICTED: exostosin-1c-like [Fundulus hetero...  NW_012224643.1
#
#              product          gene     GeneID   transcript_id
# 0  exostosin-1c-like  LOC105917394  110366876  XR_002427042.1
# 1  exostosin-1c-like  LOC105917394  105917378  XM_021310386.1
# 2  exostosin-1c-like  LOC105917394  105917379  XM_021310387.1
# 3  exostosin-1c-like  LOC105917394  110366870  XR_002427040.1
# 4  exostosin-1c-like  LOC105917394  105917391  XM_012852186.2
#                      contig          seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN73231_c1_g1_i1  Transcript_10      0  122     122  831499494
# 1  TRINITY_DN32508_c0_g1_i1  Transcript_41      0   73      73  831575894
# 2  TRINITY_DN32524_c1_g1_i1  Transcript_58      1   54      53  831483578
# 3  TRINITY_DN32538_c0_g1_i1  Transcript_70     81  190     109  831549865
# 4  TRINITY_DN32585_c0_g1_i1  Transcript_75    155  240      85  831475751
#
#      NCBI.protein                                              Notes  \
# 0  XP_012710103.1   PREDICTED: ERI1 exoribonuclease 2 [Fundulus h...
# 1  XP_012736574.1   PREDICTED: E3 ubiquitin-protein ligase MARCH9...
# 2  XP_012735121.1   PREDICTED: corticoliberin [Fundulus heterocli...
# 3  XP_012727793.1   PREDICTED: parvalbumin, thymic CPV3-like [Fun...
# 4  XP_012708360.1   PREDICTED: leucine-rich repeat transmembrane ...
#
#   NCBI.trasncript                                       NCBI.product  \
# 0  NW_012224821.1                             ERI1 exoribonuclease 2
# 1  NW_012234529.1            E3 ubiquitin-protein ligase MARCH9-like
# 2  NW_012224494.1                                     corticoliberin
# 3  NW_012234370.1                         parvalbumin%2C thymic CPV3
# 4  NW_012224404.1  leucine-rich repeat transmembrane protein FLRT...
#
#            gene  NCBI.gene
# 0          eri2  105919335
# 1  LOC105939084  105939110
# 2           crh  105937907
# 3  LOC105932983  105933022
# 4  LOC105917946  105916749
# (30706, 12)
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (77688, 5)
# Unique Fhet genes: (22994, 5)
#              seqid_x                                               Name  \
# 0  Transcript_100263  gi|831554709|ref|XP_012729460.1| PREDICTED: mu...
# 1  Transcript_100263  gi|831554709|ref|XP_012729460.1| PREDICTED: mu...
# 2  Transcript_100263  gi|831554709|ref|XP_012729460.1| PREDICTED: mu...
# 3  Transcript_100263  gi|831554709|ref|XP_012729460.1| PREDICTED: mu...
# 4  Transcript_100263  gi|831554709|ref|XP_012729460.1| PREDICTED: mu...
#
#    start  end  length         id      protein_id  \
# 0      0  122     122  831554709  XP_012729460.1
# 1      0  122     122  831554709  XP_012729460.1
# 2      0  122     122  831554709  XP_012729460.1
# 3      0  122     122  831554709  XP_012729460.1
# 4      0  122     122  831554709  XP_012729460.1
#
#                                                Notes         seqid_y  \
# 0   PREDICTED: multidrug resistance-associated pr...  NW_012234394.1
# 1   PREDICTED: multidrug resistance-associated pr...  NW_012234394.1
# 2   PREDICTED: multidrug resistance-associated pr...  NW_012234394.1
# 3   PREDICTED: multidrug resistance-associated pr...  NW_012234394.1
# 4   PREDICTED: multidrug resistance-associated pr...  NW_012234394.1
#
#                                      product    gene     GeneID  \
# 0  multidrug resistance-associated protein 9  abcc12  105934121
# 1  multidrug resistance-associated protein 9  abcc12  105934136
# 2  multidrug resistance-associated protein 9  abcc12  105934136
# 3  multidrug resistance-associated protein 9  abcc12  105934136
# 4  multidrug resistance-associated protein 9  abcc12  105934144
#
#     transcript_id
# 0  XM_021322283.1
# 1  XM_012873992.2
# 2  XM_012873993.2
# 3  XM_012873994.2
# 4  XM_012874005.2
#                      contig           seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN81334_c0_g1_i1   Transcript_95     28   90      62  831497731
# 1  TRINITY_DN56987_c0_g1_i1  Transcript_166      0   72      72  831491849
# 2  TRINITY_DN48616_c0_g1_i1  Transcript_233     62   86      24  831484829
# 3  TRINITY_DN33983_c0_g1_i1  Transcript_586      5   40      35  831576519
# 4  TRINITY_DN33983_c0_g2_i1  Transcript_587      0   23      23  831576519
#
#      NCBI.protein                                              Notes  \
# 0  XP_012709482.1   PREDICTED: nuclear receptor ROR-alpha-like is...
# 1  XP_012707401.1   PREDICTED: protein delta homolog 1 [Fundulus ...
# 2  XP_012704828.1   PREDICTED: homeobox protein goosecoid-2 [Fund...
# 3  XP_012736794.1   PREDICTED: uncharacterized protein LOC1059392...
# 4  XP_012736794.1   PREDICTED: uncharacterized protein LOC1059392...
#
#   NCBI.trasncript                                NCBI.product          gene  \
# 0  NW_012224770.1  nuclear receptor ROR-alpha-like isoform X2  LOC105918865
# 1  NW_012224631.1                     protein delta homolog 1          dlk1
# 2  NW_012224516.1                homeobox protein goosecoid-2          gsc2
# 3  NW_012234534.1        uncharacterized protein LOC105939251  LOC105939251
# 4  NW_012234534.1        uncharacterized protein LOC105939251  LOC105939251
#
#    NCBI.gene
# 0  110367056
# 1  105917211
# 2  105915293
# 3  105939231
# 4  105939231
# (23987, 12)

# %%
table_file = "F_catanatus_genenames.csv"
species = "F_catanatus"
table = pd.read_csv(Fhet_counts_dir + table_file)
print("Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig):",table.groupby('seqid').count().shape)
print("Unique Fhet genes:",table.groupby('Name').count().shape)
table['split_1'], table['split_2'], table['split_3'],table['split_4'],table['split_5'] = table['Name'].str.split('|',0).str
table.columns = ['index','seqid', 'Name', 'start', 'end', 'length', 'split_1', 'id','split_3', 'protein_id', 'Notes']
table = table[['seqid', 'Name', 'start', 'end', 'length', 'id','protein_id', 'Notes']]
table = pd.merge(table,protein_transcript,how="inner",on="protein_id")
table = table.drop_duplicates(subset='seqid_x')[['seqid_x', 'Name', 'start', 'end', 'length', 'id','protein_id', 'Notes']]
table = table[['seqid_x', 'start', 'end', 'length', 'id','protein_id', 'Notes']]
table.columns = ['seqid', 'start', 'end', 'length', 'NCBI.id','protein_id', 'Notes']
conversion_file = [i for i in conversions if i.startswith(species)][0]
conversion = pd.read_csv(conversion_dir + conversion_file)
conversion['contig'], conversion['info'] = conversion['original'].str.split(' ', 1).str
conversion = conversion[['contig','renamed']]
conversion.columns = ['contig','seqid']
table = pd.merge(conversion, table, on="seqid")
print(table.head())
# Out:
# Contigs (one Fhet gene selected, best E-value < 1E-05 match per contig): (78538, 5)
# Unique Fhet genes: (22435, 5)
#                      contig           seqid  start  end  length    NCBI.id  \
# 0  TRINITY_DN56902_c1_g1_i1  Transcript_160      0  113     113  831490423
# 1  TRINITY_DN56910_c0_g1_i1  Transcript_165      1  140     139  831535516
# 2   TRINITY_DN7043_c0_g1_i1  Transcript_177      0  109     109  831510576
# 3  TRINITY_DN64187_c0_g1_i1  Transcript_240      0  225     225  831501107
# 4  TRINITY_DN64187_c0_g2_i1  Transcript_241      0  187     187  831501107
#
#        protein_id                                              Notes
# 0  XP_012706902.1   PREDICTED: cell death activator CIDE-B [Fundu...
# 1  XP_012722638.1   PREDICTED: neuroligin-3-like isoform X2 [Fund...
# 2  XP_012713947.1   PREDICTED: UDP-glucuronosyltransferase 2A1-li...
# 3  XP_012710668.1   PREDICTED: F-box only protein 39 [Fundulus he...
# 4  XP_012710668.1   PREDICTED: F-box only protein 39 [Fundulus he...
